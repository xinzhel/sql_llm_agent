# %%
from utils import read_templates
from generate_eval_data import generate_eval_data

# %% [markdown]
# ### Read SQL Templates, Text Templates and Placeholders

# %%
templates_all_entities, sql_templates_all_entities, placeholders_all_entities, text_templates_all_entities = read_templates("templates/text/long_for_each_table.json")
# Out:
# Number of SQL templates for each table:
# Project 7
# Capability 2
# Employee 12
# Company 6
# Total number of templates:  27

# %% [markdown]
# ### Generate SQL Queries, Answers and Text Queries

# %%
generate_eval_data(sql_templates_all_entities, text_templates_all_entities, placeholders_all_entities)
# Out:
# Table name:  Project
# The number of generated SQL queries for the table Project:  45
# The number of generated text queries for the table Project:  78
# Table name:  Capability
# The number of generated SQL queries for the table Capability:  12
# The number of generated text queries for the table Capability:  18
# Table name:  Employee
# The number of generated SQL queries for the table Employee:  33
# The number of generated text queries for the table Employee:  84
# Table name:  Company
# The number of generated SQL queries for the table Company:  12
# The number of generated text queries for the table Company:  36
# {'Project': [[("[('Carlton Innovation Precinct', 'Melbourne, Victoria', 'inactive')]",
#     ['1. This action seeks to find the name, location, and status of a project that has the exact same name as the one specified, which is "Carlton Innovation Precinct".',
# ...
